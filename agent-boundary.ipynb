# %%
# !uv pip install torch
# Out:
# Resolved 10 packages in 345ms
# ⠙ Preparing packages... (0/6)
# ⠙ Preparing packages... (0/6)-------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/523.63 KiB
# mpmath               ------------------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/982.64 KiB
# mpmath               ------------------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/982.64 KiB
# mpmath               ------------------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/982.64 KiB
# filelock             ------------------------------     0 B/26.13 KiB
# mpmath               ------------------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/982.64 KiB
# filelock             ------------------------------     0 B/26.13 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# ...
